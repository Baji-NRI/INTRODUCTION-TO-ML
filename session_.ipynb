# %% [markdown]
# <a href="https://colab.research.google.com/github/Baji-NRI/INTRODUCTION-TO-ML/blob/main/session_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Expression and statement

# Expression -> Result

# it contains atleast one assignment operator
# = += -=...
#Expression tells about how a variable is being manipulated
#results
#statement-> action
#statement tells us to perform on action
#inside a statement you can have an expression
#control system

#Difference between statement and Expression

      #Expression                                    #statement

   #produces a value.                                #perform an action
   #it can be inside a statement                     #cannot inside expression
   #used for calculation                             #used to control program

     #Examples

   #calculating bill.                                #paying a bill


   #conditional statement

   #Expression evaluating based on a specific condition
   #if/else/elif

      #if(condition){
      #.        Expressions\statements
      #              }


      #elif(condition){
      #.        Expressions\statements
      #.             }

      #else {
      #.        Expressions\statements
      #.             }
