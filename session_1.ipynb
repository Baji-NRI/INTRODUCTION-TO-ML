# %% [markdown]
# <a href="https://colab.research.google.com/github/Baji-NRI/INTRODUCTION-TO-ML/blob/main/session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Testing the variables and print function

# %%
name = "mukhesh"
age = 20
GPA = 9.0
is_student =True

# %%
print (age)
# Out:
# 20

# %%
print(name)
# Out:
# mukhesh

# %%
print(GPA)
# Out:
# 9.0

# %%
print(is_student)
# Out:
# True

# %% [markdown]
# Formatting a string
# >pass "f" before "or" inside the paratheses function curly barce for the variables

# %%
print(f"student name is {name} his/her age is {age} his/her GPA is {GPA}")
# Out:
# student name is mukhesh his/her age is 20 his/her GPA is 9.0

# %%
introduction_line = f"MY name is {name}, im {age} years old"

# %%
introduction_line
# Out:
# 'MY name is mukhesh, im 20 years old'

# %% [markdown]
# type(obj) = it is used find the data type of the object

# %%
 print(type(name))
# Out:
# <class 'str'>

# %%
print(type(GPA))
# Out:
# <class 'float'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print (type(is_student))
# Out:
# <class 'bool'>
