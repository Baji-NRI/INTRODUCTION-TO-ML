# %% [markdown]
# <a href="https://colab.research.google.com/github/Baji-NRI/INTRODUCTION-TO-ML/blob/main/Session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Testing the variables with print function

# %%
name = "Baji"
age = 20
GPA = 9.0
Height = 5.11
is_student = True

# %%
print(name)
# Out:
# Baji

# %%
 print(age)
# Out:
# 20

# %%
print(GPA)
# Out:
# 9.0

# %%
print(Height)
# Out:
# 5.11

# %%
print (is_student)
# Out:
# True

# %% [markdown]
# Formatting a string
# >Pass "f" before ""or"" inside
# the parantheses of print
# function

# %%
print(f"student name is {name} his/her age is {age} his/her GPA is {GPA}")
# Out:
# student name is Baji his/her age is 20 his/her GPA is 9.0

# %%
introductionLine = f"My name is {name}, I'm {age} years old"

# %%
 print(introductionLine)
# Out:
# My name is Baji, I'm 20 years old

# %% [markdown]
# type(obj)-Gives out the data type for the variable we are used

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type (is_student))
# Out:
# <class 'bool'>
